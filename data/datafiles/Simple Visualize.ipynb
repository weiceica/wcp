# %%
import tensorflow as tf
import pandas as pd
import numpy as np

# %%
df2 = pd.read_csv("WorldCupMatches.csv")
df2.head()
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                   3.0                   0.0
# ...

# %%
df1 = pd.read_csv("rankings.csv") 
df1.head()
# Out:
#    Unnamed: 0  rankings  countries   points
# 0           0         1     Brazil  1837.56
# 1           1         2    Belgium  1821.92
# 2           2         3  Argentina  1770.65
# 3           3         4     France  1764.85
# 4           4         5    England  1737.46

# %%
df2.columns
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'rankings', 'countries', 'points'], dtype='object')

# %%
df2 = pd.read_csv("WorldCupMatchesSorted.csv")

# %%
df2
# Out:
#       Unnamed: 0 Home Team Name  Home Team Goals  Away Team Goals  \
# 0              0         France              4.0              1.0
# 1              1            USA              3.0              0.0
# 2              2     Yugoslavia              2.0              1.0
# 3              3        Romania              3.0              1.0
# 4              4      Argentina              1.0              0.0
# ...          ...            ...              ...              ...
# 4567        4567            NaN              NaN              NaN
# 4568        4568            NaN              NaN              NaN
# 4569        4569            NaN              NaN              NaN
# 4570        4570            NaN              NaN              NaN
# 4571        4571            NaN              NaN              NaN
#
#      Away Team Name
# 0            Mexico
# 1           Belgium
# 2            Brazil
# 3              Peru
# 4            France
# ...             ...
# 4567            NaN
# ...

# %%
#swort data
df2.drop(df2.index[850:4572], inplace=True)
df2
# Out:
#      Unnamed: 0 Home Team Name  Home Team Goals  Away Team Goals  \
# 0             0         France              4.0              1.0
# 1             1            USA              3.0              0.0
# 2             2     Yugoslavia              2.0              1.0
# 3             3        Romania              3.0              1.0
# 4             4      Argentina              1.0              0.0
# ..          ...            ...              ...              ...
# 845         845         Brazil              2.0              1.0
# 846         846      Argentina              1.0              0.0
# 847         847    Netherlands              0.0              0.0
# 848         848         Brazil              1.0              7.0
# 849         849    Netherlands              0.0              0.0
#
#     Away Team Name
# 0           Mexico
# 1          Belgium
# 2           Brazil
# 3             Peru
# 4           France
# ..             ...
# 845       Colombia
# 846        Belgium
# ...

# %%
df1
# Out:
#      Unnamed: 0  rankings               countries   points
# 0             0         1                  Brazil  1837.56
# 1             1         2                 Belgium  1821.92
# 2             2         3               Argentina  1770.65
# 3             3         4                  France  1764.85
# 4             4         5                 England  1737.46
# ..          ...       ...                     ...      ...
# 206         206       207               Sri Lanka   825.25
# 207         207       208       US Virgin Islands   823.97
# 208         208       209  British Virgin Islands   809.32
# 209         209       210                Anguilla   790.74
# 210         210       211              San Marino   763.82
#
# [211 rows x 4 columns]

# %%
#now the data is all ready to go.

# %%
#visualize our data that we have first
df1.describe()
# Out:
#        Unnamed: 0   rankings       points
# count   211.00000  211.00000   211.000000
# mean    105.00000  106.00000  1220.645592
# std      61.05462   61.05462   253.331712
# min       0.00000    1.00000   763.820000
# 25%      52.50000   53.50000  1008.330000
# 50%     105.00000  106.00000  1183.900000
# 75%     157.50000  158.50000  1431.790000
# max     210.00000  211.00000  1837.560000

# %%
df1.drop(['Unnamed: 0'], axis=1)
# Out:
#      rankings               countries   points
# 0           1                  Brazil  1837.56
# 1           2                 Belgium  1821.92
# 2           3               Argentina  1770.65
# 3           4                  France  1764.85
# 4           5                 England  1737.46
# ..        ...                     ...      ...
# 206       207               Sri Lanka   825.25
# 207       208       US Virgin Islands   823.97
# 208       209  British Virgin Islands   809.32
# 209       210                Anguilla   790.74
# 210       211              San Marino   763.82
#
# [211 rows x 3 columns]

# %%
# I think main contenders will be France, Spain, Argentina, Brazil
# lets visualize these
FranceH_df = df2[df2['Home Team Name'] == "France"] 
FranceA_df = df2[df2['Away Team Name'] == 'France']
France_df = FranceH_df.append(FranceA_df, ignore_index=True)
France_df
# Out:
# C:\Users\weice\AppData\Local\Temp\ipykernel_1628\4053557760.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   France_df = FranceH_df.append(FranceA_df, ignore_index=True)
#     Unnamed: 0 Home Team Name  Home Team Goals  Away Team Goals Away Team Name
# 0            0         France              4.0              1.0         Mexico
# 1           37         France              3.0              1.0        Belgium
# 2           85         France              3.0              2.0         Mexico
# 3          105         France              7.0              3.0       Paraguay
# 4          122         France              2.0              1.0       Scotland
# ..         ...            ...              ...              ...            ...
# 56         705       Portugal              0.0              1.0         France
# 57         707          Italy              1.0              1.0         France
# ...

# %%
SpainH_df = df2[df2['Home Team Name'] == "Spain"] 
SpainA_df = df2[df2['Away Team Name'] == 'Spain']
Spain_df = SpainH_df.append(SpainA_df, ignore_index=True)
Spain_df
# Out:
# C:\Users\weice\AppData\Local\Temp\ipykernel_1628\1146903747.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Spain_df = SpainH_df.append(SpainA_df, ignore_index=True)
#     Unnamed: 0    Home Team Name  Home Team Goals  Away Team Goals  \
# 0           23             Spain              3.0              1.0
# 1           55             Spain              3.0              1.0
# 2           60             Spain              2.0              0.0
# 3           64             Spain              1.0              0.0
# 4          149             Spain              1.0              0.0
# 5          177             Spain              2.0              1.0
# 6          291             Spain              1.0              0.0
# 7          316             Spain              1.0              1.0
# 8          328             Spain              2.0              1.0
# ...

# %%
ArgentinaH_df = df2[df2['Home Team Name'] == "Argentina"] 
ArgentinaA_df = df2[df2['Away Team Name'] == 'Argentina']
Argentina_df = ArgentinaH_df.append(ArgentinaA_df, ignore_index=True)
BrazilH_df = df2[df2['Home Team Name'] == "Brazil"] 
BrazilA_df = df2[df2['Away Team Name'] == 'Brazil']
Brazil_df = BrazilH_df.append(BrazilA_df, ignore_index=True)
# Out:
# C:\Users\weice\AppData\Local\Temp\ipykernel_1628\623740630.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Argentina_df = ArgentinaH_df.append(ArgentinaA_df, ignore_index=True)
# C:\Users\weice\AppData\Local\Temp\ipykernel_1628\623740630.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Brazil_df = BrazilH_df.append(BrazilA_df, ignore_index=True)

# %%
import matplotlib.pyplot as plt
plt.clf()
plt.hist(ArgentinaH_df["Home Team Goals"])
plt.show()

# %%
plt.clf()
plt.hist(ArgentinaA_df["Away Team Goals"])
plt.show()

# %%
plt.clf()
plt.hist(BrazilH_df["Home Team Goals"])
plt.show() 
plt.clf()
plt.hist(BrazilA_df["Away Team Goals"])
plt.show()

# %%
plt.clf()
plt.hist(FranceH_df["Home Team Goals"])
plt.show() 
plt.clf()
plt.hist(FranceA_df["Away Team Goals"])
plt.show()

# %%
plt.clf()
plt.hist(FranceH_df["Away Team Goals"])
plt.show() 
plt.clf()
plt.hist(FranceA_df["Home Team Goals"])
plt.show()

# %%
plt.clf()
plt.hist(SpainH_df["Away Team Goals"])
plt.show() 
plt.clf()
plt.hist(SpainA_df["Home Team Goals"])
plt.show()

# %%
plt.clf()
plt.hist(SpainH_df["Home Team Goals"])
plt.show() 
plt.clf()
plt.hist(SpainA_df["Away Team Goals"])
plt.show()
